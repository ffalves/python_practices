# %%
pip install pytrends

# %%
import pytrends 
from pytrends.request import TrendReq 
import pandas as pd
import time
import datetime
from datetime import datetime, date, time

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes = True)

# %% [markdown]
# **Trends do Google Trends dos últimos 7 dias no Brasil**
#
# ---

# %%
# Trends sobre a lista de 5 palavras-chave, de 1 mês pra cá, no BR
trend = TrendReq()
trend.build_payload(kw_list = ['filme', 'serie', 'animação', 'dublada', 'dublado'], timeframe = 'now 7-d', geo = 'BR') #today - Xm

# %%
# Trend ao longo do tempo ordenado pela data
trend.interest_over_time().sort_values(by = ['date'], ascending = False, inplace = False)
# Out:
#                      filme  serie  animação  dublada  dublado isPartial
# date
# 2022-01-27 04:00:00     72     14         1        0       16      True
# 2022-01-27 03:00:00     90     15         1        0       14     False
# 2022-01-27 02:00:00     79     16         1        0       12     False
# 2022-01-27 01:00:00     57     15         0        0       11     False
# 2022-01-27 00:00:00     50     14         0        0       10     False
# ...                    ...    ...       ...      ...      ...       ...
# 2022-01-20 09:00:00     34      5         0        0        4     False
# 2022-01-20 08:00:00     45      6         0        0        6     False
# 2022-01-20 07:00:00     63     10         1        0       14     False
# 2022-01-20 06:00:00     70     15         1        0       19     False
# 2022-01-20 05:00:00     81     16         1        0       20     False
#
# [168 rows x 6 columns]

# %%
# Dataframe
trend_df = trend.interest_over_time()
trend_df.sort_values(by = ['date'], ascending = False, inplace = True)

# %%
# Gráfico série temporal 
dx = trend_df.plot.line(figsize = (18,7), title = 'Interesse ao longo do tempo - Google Trends')
dx.set_xlabel('Data')
dx.set_ylabel('Trends Index')
dx.tick_params(axis = 'both', which = 'major', labelsize = 13)

# %%
# Related queries
trendTopics = trend.related_queries()
print(trendTopics)
# Out:
# {'filme': {'top':                       query  value
# 0                  filme de    100
# 1            filme completo     29
# 2            assistir filme     21
# 3    filme completo dublado     18
# 4             filme netflix     17
# 5                    filmes     16
# 6              filme online     11
# 7               filme globo      5
# 8          filme brasileiro      5
# 9              baixar filme      4
# 10          filme de terror      4
# 11              filme tempo      4
# 12            filme encanto      4
# 13            filme torrent      4
# 14       filme homem aranha      4
# 15  filme nasce uma estrela      3
# 16   filme eduardo e monica      2
# 17         filme globo hoje      2
# 18            filme de ação      2
# 19      filme online gratis      2
# 20               mega filme      2
# 21           filme da globo      2
# 22            eternos filme      2
# 23        filme escape room      1
# 24            patrick filme      1, 'rising':                                     query  value
# 0                escape room o jogo filme  14250
# 1                      escape room o jogo  14250
# 2                        escape room jogo  12450
# 3          filme uma razão para recomeçar   9000
# 4              filme o violino do meu pai   7850
# 5                     filme falando grego   5050
# 6                     casa de vidro filme   3100
# 7                           casa de vidro   3100
# 8                   filme a casa de vidro   2950
# 9             filme tratamento de realeza   2700
# 10                 filme inimiga perfeita   2350
# 11                     palm springs filme   1950
# 12              filme ela disse ele disse   1450
# 13                      filme escape room   1100
# 14                      the fallout filme    800
# 15                          patrick filme    500
# 16        uma chance para recomeçar filme    500
# 17                  filme a bela e a fera    500
# 18                        filme do neymar    450
# 19                       scape room filme    450
# 20                             space room    350
# 21  filme uma razão para recomeçar resumo    350
# 22                 filme eduardo e monica    190}, 'serie': {'top':                     query  value
# 0           serie netflix    100
# 1            serie neymar     36
# 2            serie online     35
# 3             serie a tim     32
# 4                  series     27
# 5         serie do neymar     22
# 6          premier league     19
# 7          italia serie a     19
# 8        serie da netflix     18
# 9                 la liga     15
# 10         serie euphoria     15
# 11           serie a 2022     14
# 12         tabela serie a     14
# 13           serie b 2022     13
# 14             bundesliga     13
# 15            serie turca     11
# 16         tabela serie b     10
# 17            apple watch      9
# 18              you serie      9
# 19     campeonato serie b      8
# 20  classificação serie a      8
# 21      pacificador serie      8
# 22         series netflix      7
# 23              max serie      7
# 24               serie a2      7, 'rising':                                 query  value
# 0   que horas lança a serie do neymar  14900
# 1     que horas sai a serie do neymar   7550
# 2            serie temporada de verao   2400
# 3             nome da serie do neymar   1950
# 4                     serie do neymar   1250
# 5                serie neymar netflix    950
# 6                        serie neymar    900
# 7                     serie de neymar    750
# 8         campeonato paulista serie a    650
# 9                        veneno serie    650
# 10                  paulista serie a2    600
# 11                      portuguesa rj    550
# 12                    carioca serie a    550
# 13         serie do neymar na netflix    550
# 14                    la veneno serie    500
# 15                        serie ozark    450
# 16                  paulista serie a1    450
# 17                           serie a2    400
# 18       campeonato paulista serie a2    350
# 19                            la liga     60}, 'animação': {'top':                        query  value
# 0            filmes animação    100
# 1                     filmes    100
# 2             filme animação     82
# 3         filmes de animação     66
# 4          filme de animação     45
# 5             fazer animação     28
# 6           animação netflix     25
# 7              animação 2021     23
# 8            animação disney     21
# 9                animação 3d     20
# 10           animação online     17
# 11       como fazer animação     14
# 12       desenho de animação     12
# 13      filmes animação 2021     10
# 14               filmes 2021     10
# 15        injustice animação      9
# 16                 injustice      9
# 17        animação da disney      9
# 18               animação 2d      9
# 19            curso animação      8
# 20  melhores filmes animação      8
# 21           melhores filmes      8
# 22                 animações      8
# 23               animação dc      8
# 24      filmes animação 2022      8, 'rising':                                         query  value
# 0                              selvagem filme    450
# 1                    selvagens filme animação    250
# 2   serie de animação futurista dos anos 1960    170
# 3                      bela e a fera animação    140
# 4                                   pencil 2d    120
# 5                          selvagens animação    110
# 6                              divertidamente     70
# 7           queijo francês de leite de ovelha     70
# 8                               adobe animate     70
# 9                            netcine animação     60
# 10                 whindersson nunes animação     60
# 11                      nova animação netflix     60
# 12                        a viagem de chihiro     50}, 'dublada': {'top':                                      query  value
# 0                                  torrent    100
# 1                             demon slayer     41
# 2                             boku no hero     39
# 3                            greys anatomy     39
# 4                         greys anatomy 18     31
# 5             euphoria 2 temporada dublada     30
# 6                     euphoria 2 temporada     30
# 7       greys anatomy 18 temporada dublada     27
# 8               greys anatomy 18 temporada     27
# 9                       shingeki no kyojin     23
# 10        demon slayer 2 temporada dublada     21
# 11                demon slayer 2 temporada     21
# 12                           one punch man     20
# 13                        kimetsu no yaiba     20
# 14                         attack on titan     16
# 15          fire force 2 temporada dublada     13
# 16         euphoria serie completa dublada     13
# 17       one punch man 2 temporada dublada     12
# 18       segunda temporada de demon slayer     11
# 19        boku no hero 5 temporada dublada     11
# 20  shingeki no kyojin 4 temporada dublada     11
# 21          shingeki no kyojin 4 temporada     11
# 22          tensei shitara slime datta ken     10, 'rising':                                 query  value
# 0                    greys anatomy 18    250
# 1  greys anatomy 18 temporada dublada    200
# 2          greys anatomy 18 temporada    200
# 3                       greys anatomy    160
# 4      tensei shitara slime datta ken    150
# 5    boku no hero 5 temporada dublada     80}, 'dublado': {'top':                               query  value
# 0                     filme dublado    100
# 1            filme completo dublado     77
# 2                          assistir     73
# 3                           torrent     13
# 4   assistir filme completo dublado     13
# 5                     anime dublado     10
# 6                     filmes online      8
# 7                      homem aranha      7
# 8                    animes dublado      6
# 9                   encanto dublado      4
# 10                 euphoria dublado      4
# 11                      mega filmes      4
# 12           assistir filmes online      4
# 13                          topflix      4
# 14             demon slayer dublado      3
# 15                   sing 2 dublado      3
# 16                   boruto dublado      3
# 17                  eternos dublado      3
# 18         encanto completo dublado      3
# 19             boku no hero dublado      3
# 20                     boku no hero      3
# 21         naruto shippuden dublado      3
# 22          tonikaku kawaii dublado      1
# 23                  tonikaku kawaii      1
# 24        nasce uma estrela dublado      1, 'rising':                                               query  value
# 0             neymar o caos perfeito online dublado   3400
# 1         uma razão para recomeçar completo dublado   2650
# 2                               miraculous kuroneko   2550
# 3   uma razão para recomeçar filme completo dublado   2000
# 4              kuroneko miraculous completo dublado   1800
# 5           bagunça na praia filme completo dublado   1100
# 6                     ookami to koushinryou dublado    600
# 7          o filho do batman filme completo dublado    450
# 8     filme eduardo e mônica filme completo dublado    250
# 9        a hora da sua morte filme completo dublado    250
# 10        filme marcas do silencio completo dublado    200
# 11                               marcas do silêncio    190
# 12                        nasce uma estrela dublado    180
# 13        marcas do silêncio filme completo dublado    170
# 14                           miraculous 4 temporada    120
# 15                                plunderer dublado    120
# 16                                       intocaveis    120
# 17                       greys anatomy 18 temporada    110
# 18               greys anatomy 18 temporada dublado    110
# 19     escape room 2 filme completo dublado youtube    100
# 20                          tonikaku kawaii dublado    100
# 21                                  tonikaku kawaii    100
# 22       encanto filme completo dublado cine vision     90}}

# %%
# Related categories
trendCategories = trend.categories()
print(trendCategories)

# %%
# Related topics
trendTopics = trend.related_topics()
print(trendTopics)
# Out:
# {}

# %%
# Suggestions 
print(trend.suggestions(keyword = 'filme'), '\n')
print(trend.suggestions(keyword = 'serie'), '\n')
print(trend.suggestions(keyword = 'animacao'), '\n')
print(trend.suggestions(keyword = 'dublada'), '\n')
print(trend.suggestions(keyword = 'dublado'), '\n')
# Out:
# [{'mid': '/m/02vxn', 'title': 'Film', 'type': 'Topic'}, {'mid': '/m/01pj_5', 'title': 'Scary Movie', 'type': '2000 film'}, {'mid': '/m/043h78', 'title': 'Scooby-Doo', 'type': 'Film'}, {'mid': '/m/02mc5v', 'title': 'Scary Movie 2', 'type': '2001 film'}, {'mid': '/m/0d90m', 'title': 'X-Men', 'type': 'Film'}]
#
# [{'mid': '/m/03zv9', 'title': 'Serie A', 'type': 'Football league'}, {'mid': '/m/0fnk7q', 'title': 'Campeonato Brasileiro Série A', 'type': 'Football league'}, {'mid': '/m/0fnkb5', 'title': 'Campeonato Brasileiro Série B', 'type': 'Football league'}, {'mid': '/m/02kqqt', 'title': 'Serie B', 'type': 'Football league'}, {'mid': '/m/0fjp3', 'title': 'World Series', 'type': 'Sports league championship'}]
#
# [{'mid': '/g/11bxxdvrjy', 'title': 'Papageno', 'type': '1935 film'}, {'mid': '/g/11g7_fp5qm', 'title': 'Termas de São Pedro do Sul', 'type': 'Thermal baths in São Pedro do Sul, Portugal'}, {'mid': '/m/02qky2n', 'title': 'Instituto Superior de Lisboa e Vale do Tejo (ISCE)', 'type': 'Higher educational institution in Odivelas, Portugal'}, {'mid': '/g/11g_tf5l2', 'title': 'Faculdade Melies de Tecnologia', 'type': 'College in São Paulo, Brazil'}, {'mid': '/g/1pv5tlpz4', 'title': 'Jornal de Gramado', 'type': 'Newspaper publisher in Gramado, Brazil'}]
#
# [{'mid': '/m/0zrxc1v', 'title': 'The Cobbler', 'type': '2014 film'}, {'mid': '/m/0_g1h3j', 'title': 'The House of Magic', 'type': '2013 film'}, {'mid': '/g/11clw8kpc7', 'title': 'Busco novio para mi mujer', 'type': '2016 film'}, {'mid': '/m/017jd9', 'title': 'The Lord of the Rings: The Return of the King', 'type': '2003 film'}, {'mid': '/m/0gm12h6', 'title': 'The Boathouse Detectives', 'type': '2010 film'}]
#
# [{'mid': '/g/11c61hb1f0', 'title': 'Venom', 'type': '2018 film'}, {'mid': '/g/11d_7x5tjx', 'title': 'Spider-Man: Far from Home', 'type': '2019 film'}, {'mid': '/m/0wkgbxq', 'title': 'Spider-Man: Homecoming', 'type': '2017 film'}, {'mid': '/m/0crrc8', 'title': 'How the Grinch Stole Christmas', 'type': '2000 film'}, {'mid': '/g/11bz0yq44d', 'title': 'The Grinch', 'type': 'Film'}]

# %% [markdown]
# **Trends do YouTube Trends dos últimos 7 dias no Brasil**
#
# ---

# %%
# Trends no YT
yt = TrendReq()
yt.build_payload(kw_list = ['filme', 'serie', 'animação', 'dublada', 'dublado'], timeframe = 'now 7-d', geo = 'BR', gprop = 'youtube')

# %%
# Trend ao longo do tempo ordenado pela data
yt.interest_over_time().sort_values(by = ['date'], ascending = False, inplace = False)
# Out:
#                      filme  serie  animação  dublada  dublado isPartial
# date
# 2022-01-27 04:00:00     62      2         3        0       34      True
# 2022-01-27 03:00:00     64      3         2        0       34     False
# 2022-01-27 02:00:00     75      2         2        0       40     False
# 2022-01-27 01:00:00     81      2         2        0       42     False
# 2022-01-27 00:00:00     81      2         1        0       42     False
# ...                    ...    ...       ...      ...      ...       ...
# 2022-01-20 09:00:00     36      1         1        0       20     False
# 2022-01-20 08:00:00     38      1         1        0       24     False
# 2022-01-20 07:00:00     44      3         1        0       28     False
# 2022-01-20 06:00:00     46      2         2        0       29     False
# 2022-01-20 05:00:00     54      3         2        0       34     False
#
# [168 rows x 6 columns]

# %%
# Dataframe
yt_df = yt.interest_over_time()
yt_df.sort_values(by = ['date'], ascending = False, inplace = True)

# %%
# Gráfico série temporal 
dx = yt_df.plot.line(figsize = (18,7), title = 'Interesse ao longo do tempo - YouTube Trends')
dx.set_xlabel('Data')
dx.set_ylabel('Trends Index')
dx.tick_params(axis = 'both', which = 'major', labelsize = 13)

# %%
# Related queries
ytQueries = yt.related_queries()
print(ytQueries)
# Out:
# {'filme': {'top':                              query  value
# 0                   filme completo    100
# 1                    filme dublado     63
# 2           filme completo dublado     55
# 3                    desenho filme     23
# 4                       filme ação     21
# 5                    filme de ação     19
# 6                 filme de desenho     18
# 7                     filme terror     11
# 8                    comedia filme     10
# 9                  filme de terror      9
# 10                filme de comedia      8
# 11                      filme 2022      7
# 12                   filme encanto      6
# 13                  filme infantil      5
# 14          encanto filme completo      5
# 15               filme terror 2021      4
# 16  encanto filme completo dublado      4
# 17                  filme suspense      4
# 18              filme de ação 2021      4
# 19                   filme comédia      4
# 20            filme de terror 2021      3
# 21           filme lançamento 2021      3
# 22                    filme gospel      3
# 23                      filme luta      3
# 24               filme de suspense      3, 'rising':                                                 query  value
# 0   50 tons de cinza filme completo em portugues d...   2050
# 1                      uma razao para recomeçar filme   1250
# 2                             garantia de morte filme    190
# 3                             filme nasce uma estrela    130
# 4                      procurando nemo filme completo    120
# 5                escape room 2 filme completo dublado    120
# 6                      a bela e a fera filme completo     90
# 7                        bela e a fera filme completo     90
# 8                                 nemo filme completo     70
# 9                  vingadores ultimato filme completo     50
# 10                  anaconda 2 filme completo dublado     40}, 'serie': {'top':                           query  value
# 0                serie completa    100
# 1               minecraft serie     87
# 2                   serie turca     60
# 3                    serie gold     49
# 4                 serie netflix     39
# 5                        series     35
# 6   pablo escobar serie dublado     28
# 7                         série     26
# 8                        jikook     23
# 9                  serie neymar     22
# 10                    web serie     19
# 11           bright minds serie     18
# 12                 naruto serie     14
# 13                         swat     12
# 14                   swat serie     12
# 15                rebelde serie     11
# 16           sobrenatural serie     10
# 17                 sobrenatural     10
# 18              serie do neymar      7
# 19              cuphead a serie      2
# 20              serie de neymar      2
# 21       serie aroma de morango      2
# 22              casemiro neymar      2
# 23      euphoria serie original      0, 'rising':                      query  value
# 0          casemiro neymar  12900
# 1          serie do neymar   2150
# 2             serie neymar   1050
# 3          serie de neymar    750
# 4  euphoria serie original    450
# 5   serie aroma de morango    300
# 6          cuphead a serie    150
# 7                     swat     80
# 8               swat serie     80}, 'animação': {'top':                                        query  value
# 0                                whindersson    100
# 1                 whindersson nunes animação     99
# 2                          whindersson nunes     99
# 3                             minha história     63
# 4                 minha história em animação     62
# 5                             filme animação     37
# 6                         minecraft animação     30
# 7                            filmes animação     26
# 8                          filme de animação     19
# 9                         filmes de animação     17
# 10           filme animação completo dublado     16
# 11                 filmes completos animação     10
# 12                     animação vs minecraft     10
# 13                       como fazer animação     10
# 14        filmes animação completos dublados      9
# 15                     animação de minecraft      7
# 16        filme de animação completo dublado      4
# 17                                     saiko      4
# 18                                  selvagem      4
# 19  selvagem filme completo dublado animação      3
# 20                        injustice animação      1, 'rising':                                       query  value
# 0  selvagem filme completo dublado animação    200
# 1                                  selvagem    180
# 2                        injustice animação     60}, 'dublada': {'top':                                                query  value
# 0                                             novela    100
# 1                                    novela completa     85
# 2                                      te dou a vida     16
# 3                               te dou a vida novela     16
# 4                                       novela turca      7
# 5                                    novela mexicana      6
# 6                                   rebelde mexicano      5
# 7                       rebelde mexicano 1 temporada      5
# 8                           sila prisioneira do amor      3
# 9   novela sila prisioneira do amor completa dublada      3
# 10                              se nos deixam novela      3
# 11                    novela teresa completa dublada      2
# 12           novelas mexicanas dubladas em portugues      2
# 13                                          dr house      2
# 14             assistir novela rubi completa dublada      0, 'rising':                                    query  value
# 0  assistir novela rubi completa dublada    200
# 1                   se nos deixam novela    110}, 'dublado': {'top':                                                 query  value
# 0                                       filme dublado    100
# 1                              filme completo dublado     88
# 2                      eu a patroa e as crian dublado     15
# 3                                    faroeste dublado      7
# 4                      encanto filme completo dublado      7
# 5                              encanto filme completo      7
# 6                            desenho completo dublado      6
# 7                                       gacha dublado      5
# 8                               filme de ação dublado      5
# 9                                  gacha life dublado      5
# 10                     desenho filme completo dublado      4
# 11                                     boruto dublado      3
# 12                     filme de ação completo dublado      3
# 13                  filme de desenho completo dublado      3
# 14                   filme de terror completo dublado      2
# 15            miraculous 4 temporada completo dublado      0
# 16                  anaconda 2 filme completo dublado      0
# 17                                   nagatoro dublado      0
# 18                     aladdin filme completo dublado      0
# 19                            game of thrones dublado      0
# 20  50 tons de cinza filme completo em portugues d...      0
# 21                  rei arthur filme completo dublado      0
# 22                madagascar 2 filme completo dublado      0
# 23                                           free guy      0
# 24           selvagem filme completo dublado animação      0, 'rising':                                                 query  value
# 0   50 tons de cinza filme completo em portugues d...   2700
# 1                             game of thrones dublado    350
# 2            selvagem filme completo dublado animação    190
# 3                 madagascar 2 filme completo dublado    140
# 4                escape room 2 filme completo dublado    130
# 5                   rei arthur filme completo dublado     80
# 6                                    nagatoro dublado     60
# 7             miraculous 4 temporada completo dublado     60
# 8                                            free guy     50
# 9                   anaconda 2 filme completo dublado     40
# 10                     aladdin filme completo dublado     40}}

# %% [markdown]
# **Trends do Google Trends dos últimos 7 dias no Brasil - A partir da Categoria\**

# %%
# Trends from category 34 Movies - Ref: https://github.com/pat310/google-trends-api/wiki/Google-Trends-Categories
cat = TrendReq()
cat.build_payload(kw_list = ['filme', 'serie', 'animação', 'dublada', 'dublado'], timeframe = 'now 7-d', geo = 'BR', cat = 34)

# %%
# Trend ao longo do tempo ordenado pela data
cat.interest_over_time().sort_values(by = ['date'], ascending = False, inplace = False)
# Out:
#                      filme  serie  animação  dublada  dublado isPartial
# date
# 2022-01-27 04:00:00     56      2         0        0        2      True
# 2022-01-27 03:00:00     67      2         0        0        2     False
# 2022-01-27 02:00:00     67      2         0        0        2     False
# 2022-01-27 01:00:00     53      2         0        0        2     False
# 2022-01-27 00:00:00     48      2         0        0        2     False
# ...                    ...    ...       ...      ...      ...       ...
# 2022-01-20 09:00:00     24      1         0        0        1     False
# 2022-01-20 08:00:00     31      1         0        0        1     False
# 2022-01-20 07:00:00     45      3         0        0        2     False
# 2022-01-20 06:00:00     60      3         0        0        4     False
# 2022-01-20 05:00:00     72      3         0        0        3     False
#
# [168 rows x 6 columns]

# %%
# Dataframe
cat_df = cat.interest_over_time()
cat_df.sort_values(by = ['date'], ascending = False, inplace = True)

# %%
# Gráfico série temporal 
dx = cat_df.plot.line(figsize = (18,7), title = 'Interesse ao longo do tempo - Google Trends - Categorias')
dx.set_xlabel('Data')
dx.set_ylabel('Trends Index')
dx.tick_params(axis = 'both', which = 'major', labelsize = 13)

# %%
# Related queries
catQueries = cat.related_queries()
print(catQueries)
# Out:
# {'filme': {'top':                       query  value
# 0                  filme de    100
# 1            assistir filme     36
# 2             filme netflix     30
# 3            filme completo     25
# 4              filme online     16
# 5              filme terror      9
# 6           filme de terror      8
# 7        filme homem aranha      7
# 8              filme gratis      7
# 9   filme nasce uma estrela      6
# 10             baixar filme      6
# 11    assistir filme online      6
# 12            filme torrent      6
# 13            filme encanto      5
# 14   filme eduardo e monica      4
# 15             filme panico      4
# 16            eternos filme      4
# 17              filme tempo      4
# 18         filme da netflix      4
# 19      filme online gratis      3
# 20               mega filme      3
# 21         filme de comédia      3
# 22      casa de vidro filme      2
# 23            casa de vidro      2
# 24            patrick filme      2, 'rising':                                   query  value
# 0                 filme a casa de vidro   4550
# 1                   casa de vidro filme   4300
# 2                         casa de vidro   4300
# 3     filme falcão manteiga de amendoim   3450
# 4                    escape room o jogo   2850
# 5              escape room o jogo filme   2850
# 6   filme o falcão manteiga de amendoim   2650
# 7                       emboscada filme   2300
# 8                    palm springs filme   2150
# 9                      o semideus filme   1600
# 10                filme munique netflix   1500
# 11             um passado sombrio filme   1350
# 12                        patrick filme   1150
# 13     escape room o jogo filme sinopse   1100
# 14                          envoy filme    950
# 15                    the fallout filme    900
# 16                filme a bela e a fera    800
# 17              filme trocando as bolas    600
# 18                    escape room filme    550
# 19                     o banquete filme    550
# 20       filme era uma vez em hollywood    450
# 21                     escape run filme    400
# 22             filme marcas do silêncio    250
# 23                         duvida filme    190
# 24               filme eduardo e monica    180}, 'serie': {'top':                             query  value
# 0                   serie netflix    100
# 1                  assistir serie     14
# 2                serie da netflix     12
# 3                    serie online     10
# 4          serie senhor dos aneis     10
# 5                serie na netflix      8
# 6              serie netflix 2022      6
# 7                    scream serie      5
# 8               pacificador serie      5
# 9                    chucky serie      4
# 10                boba fett serie      4
# 11             serie netflix 2021      3
# 12            o pacificador serie      2
# 13         serie netflix melhores      2
# 14            serie percy jackson      2
# 15                serie de terror      2
# 16           melhor serie netflix      2
# 17             nova serie netflix      2
# 18  serie senhor dos aneis amazon      2
# 19                   serie neymar      2
# 20       serie o senhor dos aneis      1
# 21      serie do senhor dos aneis      1
# 22           serie neymar netflix      1
# 23                    serie ozark      1
# 24                serie do neymar      1, 'rising':                                                 query  value
# 0                 serie amazon prime senhor dos aneis    800
# 1                                serie neymar netflix    700
# 2                          percy jackson serie elenco    600
# 3                                        serie neymar    450
# 4                         serie percy jackson estreia    450
# 5                                     serie do neymar    350
# 6                                         serie ozark    300
# 7                                 serie percy jackson    200
# 8                                serie alemão netflix    190
# 9                          percy jackson serie disney    160
# 10                             serie de percy jackson    140
# 11  eu sei o que vocês fizeram no verão passado filme    140
# 12                      a maldição da residência hill    130
# 13                               gloria serie netflix    120
# 14                                 the exorcist serie    110
# 15                      serie senhor dos aneis amazon    100
# 16                                  o demolidor serie     90
# 17                          serie do senhor dos aneis     80
# 18                                       toyboy serie     80
# 19                               serie apostando alto     70
# 20                           serie o senhor dos aneis     70
# 21                             serie do percy jackson     70
# 22                            iwo 14s pro max serie 7     60
# 23                             serie senhor dos aneis     50}, 'animação': {'top':                                 query  value
# 0                     filmes animação    100
# 1                  filmes de animação     63
# 2                      filme animação     34
# 3                   filme de animação     15
# 4                    animação netflix     14
# 5                       animação 2021     13
# 6                filmes animação 2021     11
# 7            melhores filmes animação     11
# 8         melhores filmes de animação      9
# 9             filmes animação netflix      8
# 10            filmes de animação 2021      8
# 11               filmes animação 2022      8
# 12                    animação disney      7
# 13              homem aranha animação      6
# 14         filmes de animação netflix      6
# 15            filmes de animação 2022      6
# 16           liga da justiça animação      5
# 17                 filmes dc animação      3
# 18        assistir filmes de animação      3
# 19          filmes da disney animação      3
# 20  espetacular homem aranha animação      3
# 21                 injustice animação      2
# 22                 selvagens animação      2
# 23     os melhores filmes de animação      2
# 24                           selvagem      2, 'rising':                                               query  value
# 0                                   selvagens filme    350
# 1                                    selvagem filme    350
# 2                                selvagens animação    300
# 3                                          selvagem    300
# 4                            bela e a fera animação    200
# 5                          a bela e a fera animação    200
# 6                           filmes de animação 2013    200
# 7   universo de filmes animados da dc comics filmes    180
# 8                                     studio ghibli    120
# 9                                   castelo animado    100
# 10                            nova animação netflix     80
# 11                filmes de animação torrent magnet     60
# 12                               filmes de aventura     60
# 13                          liga da justiça sombria     50
# 14                   os melhores filmes de animação     50}, 'dublada': {'top': None, 'rising': None}, 'dublado': {'top':                                                 query  value
# 0                              filme completo dublado    100
# 1                                     eternos dublado      8
# 2                                    panico 5 dublado      6
# 3                            filmes de terror dublado      4
# 4            harry potter e a pedra filosofal dublado      4
# 5                           nasce uma estrela dublado      4
# 6                       panico filme completo dublado      3
# 7                              eternos online dublado      3
# 8                             panico 5 online dublado      3
# 9              pijama listrado filme completo dublado      2
# 10       o chamado da floresta filme completo dublado      2
# 11                        o menino do pijama listrado      1
# 12     pijama listrado filme completo dublado netflix      1
# 13                                 marcas do silêncio      1
# 14                         marcas do silêncio dublado      1
# 15   nasce uma estrela filme completo dublado youtube      1
# 16   filme nasce uma estrela netflix completo dublado      0
# 17                 selvagem filme 2006 online dublado      0
# 18  filme patricia uma paixão escondida online dub...      0
# 19          marcas do silêncio filme completo dublado      0
# 20         o menini do pijama listrado online dublado      0
# 21  o falcão manteiga de amendoim filme completo d...      0
# 22          filme marcas do silencio completo dublado      0
# 23                      o chamado da floresta netflix      0, 'rising':                                                 query  value
# 0   o falcão manteiga de amendoim filme completo d...   1050
# 1                  selvagem filme 2006 online dublado    800
# 2   filme patricia uma paixão escondida online dub...    500
# 3                         o menino do pijama listrado    300
# 4      pijama listrado filme completo dublado netflix    300
# 5              pijama listrado filme completo dublado    250
# 6          o menini do pijama listrado online dublado    200
# 7                                  marcas do silêncio    180
# 8                          marcas do silêncio dublado    180
# 9                       o chamado da floresta netflix    170
# 10       o chamado da floresta filme completo dublado    160
# 11          filme marcas do silencio completo dublado    160
# 12          marcas do silêncio filme completo dublado    150
# 13   nasce uma estrela filme completo dublado youtube    150
# 14   filme nasce uma estrela netflix completo dublado    130
# 15                          nasce uma estrela dublado    110}}

# %% [markdown]
# **Trends do YouTube Trends dos últimos 7 dias no Brasil - A partir da Categoria**

# %%
# Trends from category 34 Movies in YT - Ref: https://github.com/pat310/google-trends-api/wiki/Google-Trends-Categories
CatYt = TrendReq()
CatYt.build_payload(kw_list = ['filme', 'serie', 'animação', 'dublada', 'dublado'], timeframe = 'now 7-d', geo = 'BR', cat = 34, gprop = 'youtube')

# %%
# Trend ao longo do tempo ordenado pela data
CatYt.interest_over_time().sort_values(by = ['date'], ascending = False, inplace = False)
# Out:
#                      filme  serie  animação  dublada  dublado isPartial
# date
# 2022-01-27 04:00:00     56      0         0        0        5      True
# 2022-01-27 03:00:00     56      0         0        0        6     False
# 2022-01-27 02:00:00     66      0         0        0        7     False
# 2022-01-27 01:00:00     79      0         0        0        8     False
# 2022-01-27 00:00:00     77      0         0        0        7     False
# ...                    ...    ...       ...      ...      ...       ...
# 2022-01-20 09:00:00     33      0         0        0        3     False
# 2022-01-20 08:00:00     34      0         0        0        4     False
# 2022-01-20 07:00:00     44      0         0        0        5     False
# 2022-01-20 06:00:00     43      0         1        0        5     False
# 2022-01-20 05:00:00     52      1         0        0        6     False
#
# [168 rows x 6 columns]

# %%
# Dataframe
CatYt_df = CatYt.interest_over_time()
CatYt_df.sort_values(by = ['date'], ascending = False, inplace = True)

# %%
# Gráfico série temporal 
dx = CatYt_df.plot.line(figsize = (18,7), title = 'Interesse ao longo do tempo - YouTube Trends - Categorias')
dx.set_xlabel('Data')
dx.set_ylabel('Trends Index')
dx.tick_params(axis = 'both', which = 'major', labelsize = 13)

# %%
# Related queries
CatYtQueries = CatYt.related_queries()
print(CatYtQueries)
# Out:
# {'filme': {'top':                     query  value
# 0                filme de    100
# 1          filme completo     66
# 2           comedia filme     21
# 3            filme terror     20
# 4         filme de terror     17
# 5              filme 2021     16
# 6        filme de comedia     15
# 7           filme de ação      9
# 8        filme lançamento      8
# 9           filme desenho      8
# 10          filme comédia      8
# 11      filme terror 2021      7
# 12         filme suspense      7
# 13             filme 2022      7
# 14   filme de terror 2021      7
# 15           filme gospel      6
# 16       filme de desenho      6
# 17      filme de suspense      6
# 18         filme infantil      6
# 19             filme luta      5
# 20         filme faroeste      5
# 21       filme de comédia      4
# 22          filme de luta      4
# 23  filme lançamento 2021      4
# 24          filme romance      4, 'rising':                                          query  value
# 0   falcao manteiga de amendoim filme completo   2900
# 1                      garantia de morte filme    180
# 2               procurando nemo filme completo    170
# 3             filme nasce uma estrela completo    170
# 4                      filme nasce uma estrela    150
# 5           bairro 13° distrito filme completo    120
# 6           vingadores ultimato filme completo    110
# 7                          nemo filme completo     90
# 8                 bela e a fera filme completo     90
# 9               a bela e a fera filme completo     90
# 10                                 filme moana     60
# 11                   decentes filme completo 3     50
# 12                      faroeste caboclo filme     40}, 'serie': {'top':                                query  value
# 0                      serie netflix    100
# 1                 serie homem aranha     91
# 2                    minecraft serie     68
# 3                       chucky serie     67
# 4                             chucky     67
# 5                  maquina mortifera     61
# 6   maquina mortifera serie completa     60
# 7         homem aranha serie animada     45
# 8             serie senhor dos aneis     42
# 9     espetacular homem aranha serie     31
# 10                     serie comedia     30
# 11                  robin hood serie     29
# 12                            series     21
# 13                             chuck     21
# 14      homem aranha a serie animada     20
# 15  o espetacular homem aranha serie     20
# 16                  serie de comedia     17
# 17          serie o senhor dos aneis     10
# 18                      serie neymar      5
# 19                 homem aranha jogo      5
# 20             serie superman e lois      4
# 21                              swat      4
# 22                 serie boa netflix      3
# 23                  rebelde la serie      3
# 24                   cuphead a serie      3, 'rising':                         query  value
# 0     naruto storm 4 detonado  21650
# 1           homem aranha jogo   1600
# 2             cuphead a serie    950
# 3                serie neymar    850
# 4            rebelde la serie    450
# 5                        swat    350
# 6                   lo siento    350
# 7    serie evangelica netflix    350
# 8    serie o senhor dos aneis    300
# 9       serie superman e lois    250
# 10                        ufc    200
# 11          serie boa netflix    180
# 12  operação big hero a serie    180
# 13     serie senhor dos aneis     80}, 'animação': {'top':                                        query  value
# 0                            filmes animação    100
# 1                         filmes de animação     66
# 2                             filme animação     30
# 3                          filme de animação     20
# 4                                     naruto     17
# 5                 whindersson nunes animação     13
# 6                          whindersson nunes     13
# 7                  filmes completos animação      9
# 8                             curta animação      8
# 9                    curta metragem animação      6
# 10                            curta metragem      6
# 11                      filmes animação 2021      6
# 12        filmes animação completos dublados      6
# 13               filmes de animação completo      5
# 14              filmes completos de animação      5
# 15                                  selvagem      4
# 16                   filmes de animação 2021      4
# 17     filmes de animação completos dublados      4
# 18                     homem aranha animação      4
# 19  selvagem filme completo dublado animação      3
# 20                                  among us      2
# 21                  assistir filmes animação      2
# 22                                   tio sun      1
# 23                       friday night funkin      1
# 24                filmes de animação antigos      1, 'rising':                                       query  value
# 0                                  among us    200
# 1                       naruto em português    170
# 2                                    raider    160
# 3  selvagem filme completo dublado animação    140
# 4                                  selvagem    120
# 5                       friday night funkin    120
# 6                                   tio sun     90
# 7                    whindersson nunes show     80
# 8                  assistir filmes animação     80
# 9                filmes de animação antigos     70}, 'dublada': {'top': None, 'rising': None}, 'dublado': {'top':                                            query  value
# 0                                  filme dublado    100
# 1                         filme completo dublado     79
# 2                               faroeste dublado     14
# 3        documentarios discovery channel dublado      8
# 4                         filmes de ação dublado      8
# 5                       filmes de terror dublado      8
# 6              filmes de terror completo dublado      5
# 7             comedia romantica completo dublado      4
# 8   o chamado da floresta filme completo dublado      0
# 9            madagascar 2 filme completo dublado      0
# 10     documentarios national geographic dublado      0
# 11                      floresta maldita dublado      0
# 12                        três vezes ana dublado      0
# 13               2 homens e meio ao vivo dublado      0
# 14               hercules filme completo dublado      0
# 15                        tres veces ana dublado      0
# 16                    marcas do silêncio dublado      0, 'rising':                                           query  value
# 0                    marcas do silêncio dublado    400
# 1                        tres veces ana dublado    170
# 2                        três vezes ana dublado    110
# 3           madagascar 2 filme completo dublado    100
# 4  o chamado da floresta filme completo dublado     80
# 5                      floresta maldita dublado     70
# 6     documentarios national geographic dublado     60
# 7               hercules filme completo dublado     60
# 8               2 homens e meio ao vivo dublado     50}}

# %% [markdown]
# **Trending Searches | BR**

# %%
trend.trending_searches(pn='brazil')
# Out:
#                             0
# 0                      Gremio
# 1   Juventude x Internacional
# 2         Quem saiu do BBB 22
# 3                       Vasco
# 4                    Esportes
# 5                       Sport
# 6       Campeonato Paranaense
# 7                        Avai
# 8            Bahia x Doce Mel
# 9                Harry Styles
# 10               Cupom Amazon
# 11                     MXRF11
# 12             Ludmila Ferber
# 13   Uma Razão Para Recomeçar
# 14                     Lakers
# 15                   Paysandu
# 16                Atletico go
# 17              Vasco da Gama
# 18                  Newcastle
# 19                    Marinho
